# %% [markdown]
# # Feature Engineering Analysis
#
# **Purpose:** Investigate potential new features that could improve model performance, based on insights from descriptive and inferential analysis.
#
# **Tasks:**
#
# 1. Create new features by combining existing ones (e.g., date-based features like "day of the week").
# 2. Encode categorical variables: Label encoding, One-Hot encoding, or similar techniques.
# 3. Feature scaling: Min-Max scaling, Standardization.
# 4. Feature selection techniques (e.g., based on correlation matrix, mutual information, feature importance).

# %%
import json

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats
import statsmodels.api as sm
import statsmodels.stats.api as sms

# %%
# reading data
df = pd.read_csv(r"D:\Doccuments\GitHub\End-to-End-MLOps-Pipeline\data\raw\fraud test.csv")
df.shape
# Out:
# (555719, 23)

# %%
data = df[df.columns[1:]].copy()
data.head(3)
# Out:
#   trans_date_trans_time        cc_num                              merchant  \
# 0      21/06/2020 12:14  2.291160e+15                 fraud_Kirlin and Sons
# 1      21/06/2020 12:14  3.573030e+15                  fraud_Sporer-Keebler
# 2      21/06/2020 12:14  3.598220e+15  fraud_Swaniawski, Nitzsche and Welch
#
#          category    amt   first      last gender                street  \
# 0   personal_care   2.86    Jeff   Elliott      M     351 Darlene Green
# 1   personal_care  29.84  Joanne  Williams      F      3638 Marsh Union
# 2  health_fitness  41.28  Ashley     Lopez      F  9333 Valentine Point
#
#        city  ...      lat      long  city_pop                     job  \
# 0  Columbia  ...  33.9659  -80.9355    333497     Mechanical engineer
# 1   Altonah  ...  40.3207 -110.4360       302  Sales professional, IT
# 2  Bellmore  ...  40.6729  -73.5365     34496       Librarian, public
#
#           dob                         trans_num   unix_time  merch_lat  \
# 0  19/03/1968  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391
# 1  17/01/1990  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498
# 2  21/10/1970  c81755dbbbea9d5c77f094348a7579be  1371816893  40.495810
#
#    merch_long  is_fraud
# 0  -81.200714         0
# 1 -109.960431         0
# 2  -74.196111         0
#
# [3 rows x 22 columns]

# %%
cols_div_path = r"D:\Doccuments\GitHub\End-to-End-MLOps-Pipeline\notebooks\metadata\Credit_cols_classified.json"
with open(cols_div_path,'r') as file:
    cols_division = json.load(file)
cols_division
# Out:
# {'target_col': 'is_fraud',
#  'uniq_cols': ['cc_num', 'trans_num'],
#  'num_cols': ['amt', 'city_pop'],
#  'cat_cols': ['merchant',
#   'category',
#   'first',
#   'last',
#   'gender',
#   'street',
#   'city',
#   'state',
#   'job'],
#  'loc_cols': ['long', 'lat', 'merch_lat', 'merch_long', 'zip'],
#  'time_cols': ['trans_date_trans_time', 'dob', 'unix_time']}

# %%
data["amt_per_pop"] = data["amt"] / (data["city_pop"] + 1e-6)
data["log_amt_per_pop"] = np.log1p(data["amt"]) - np.log1p(data["city_pop"])

# %% [markdown]
# This feature helps capture:
#
# - High transaction amount in small population → suspicious
# - Same amount in large city → less suspicious

# %%
data.head(3)
# Out:
#   trans_date_trans_time        cc_num                              merchant  \
# 0      21/06/2020 12:14  2.291160e+15                 fraud_Kirlin and Sons
# 1      21/06/2020 12:14  3.573030e+15                  fraud_Sporer-Keebler
# 2      21/06/2020 12:14  3.598220e+15  fraud_Swaniawski, Nitzsche and Welch
#
#          category    amt   first      last gender                street  \
# 0   personal_care   2.86    Jeff   Elliott      M     351 Darlene Green
# 1   personal_care  29.84  Joanne  Williams      F      3638 Marsh Union
# 2  health_fitness  41.28  Ashley     Lopez      F  9333 Valentine Point
#
#        city  ... city_pop                     job         dob  \
# 0  Columbia  ...   333497     Mechanical engineer  19/03/1968
# 1   Altonah  ...      302  Sales professional, IT  17/01/1990
# 2  Bellmore  ...    34496       Librarian, public  21/10/1970
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  2da90c7d74bd46a0caf3777415b3ebd3  1371816865  33.986391  -81.200714
# 1  324cc204407e99f51b0d6ca0055005e7  1371816873  39.450498 -109.960431
# 2  c81755dbbbea9d5c77f094348a7579be  1371816893  40.495810  -74.196111
#
#   is_fraud  amt_per_pop  log_amt_per_pop
# 0        0     0.000009       -11.366725
# 1        0     0.098808        -2.284920
# 2        0     0.001197        -6.704313
#
# [3 rows x 24 columns]
